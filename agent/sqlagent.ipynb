# %%
# Prosty SQL Agent dla analizy logów sieciowych
# Jupyter Notebook

# 1. Imports i konfiguracja
import os
import sqlite3
import pandas as pd
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_community.utilities.sql_database import SQLDatabase
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from langchain_community.agent_toolkits.sql.base import create_sql_agent
from langchain.agents.agent_types import AgentType

# Załaduj zmienne środowiskowe
load_dotenv()

# 2. Konfiguracja
class Config:
    DB_PATH = ".
    ./parser/logs.db"  # Zmień na swoją ścieżkę
    OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY_TEG')

# 3. Inicjalizacja LLM
llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    openai_api_key=Config.OPENAI_API_KEY,
    temperature=0,
)

print("✅ LLM zainicjalizowany")

# 4. Połączenie z bazą danych
try:
    db = SQLDatabase.from_uri(f"sqlite:///{Config.DB_PATH}")
    print("✅ Połączono z bazą danych")
    
    # Sprawdź tabele
    print("\n📋 Dostępne tabele:")
    print(db.get_table_names())
    
    # Sprawdź strukturę tabeli logs
    print("\n🔍 Struktura tabeli 'logs':")
    print(db.get_table_info(["logs"]))
    
except Exception as e:
    print(f"❌ Błąd połączenia z bazą: {e}")

# 5. Stworzenie SQL agenta
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

sql_agent = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True,  # Pokaż proces myślenia
    max_iterations=10,
    early_stopping_method="generate"
)

print("✅ SQL Agent utworzony")

# 6. Funkcja pomocnicza do testowania
def zapytaj_agenta(pytanie):
    """
    Zadaj pytanie SQL agentowi
    """
    print(f"\n🤔 PYTANIE: {pytanie}")
    print("="*60)
    
    try:
        odpowiedz = sql_agent.invoke({"input": pytanie})
        print(f"\n✅ ODPOWIEDŹ:")
        print(odpowiedz['output'])
        return odpowiedz
    except Exception as e:
        print(f"❌ BŁĄD: {e}")
        return None

# 7. Sprawdzenie danych w bazie
print("\n🔍 Sprawdzanie zawartości bazy...")

# Podstawowe statystyki
conn = sqlite3.connect(Config.DB_PATH)
cursor = conn.cursor()

# Liczba rekordów
cursor.execute("SELECT COUNT(*) FROM logs")
total_rows = cursor.fetchone()[0]
print(f"📊 Całkowita liczba rekordów: {total_rows}")

# Zakres dat
cursor.execute("SELECT MIN(date) as min_date, MAX(date) as max_date FROM logs")
date_range = cursor.fetchone()
print(f"📅 Zakres dat: {date_range[0]} - {date_range[1]}")

# Top 5 użytkowników
cursor.execute("SELECT srcname, COUNT(*) as count FROM logs GROUP BY srcname ORDER BY count DESC LIMIT 5")
top_users = cursor.fetchall()
print(f"\n👥 Top 5 użytkowników:")
for user, count in top_users:
    print(f"  - {user}: {count} sesji")

# Top 5 aplikacji
cursor.execute("SELECT app, COUNT(*) as count FROM logs GROUP BY app ORDER BY count DESC LIMIT 5")
top_apps = cursor.fetchall()
print(f"\n📱 Top 5 aplikacji:")
for app, count in top_apps:
    print(f"  - {app}: {count} sesji")

conn.close()

# 8. Przykładowe pytania do testowania
print("\n🧪 TESTY AGENTA")
print("="*60)

# Test 1: Podstawowe zapytanie
zapytaj_agenta("Ile rekordów jest w tabeli logs?")

# Test 2: Zapytanie o użytkownika
zapytaj_agenta("Pokaż mi 5 najaktywniejszych użytkowników")

# Test 3: Zapytanie o aplikacje
zapytaj_agenta("Które aplikacje są najczęściej używane?")

# Test 4: Zapytanie o czas
zapytaj_agenta("Jaki jest całkowity czas spędzony przez użytkownika Dawid w aplikacjach?")

# Test 5: Zapytanie o kategorie
zapytaj_agenta("Pokaż podział na kategorie aplikacji (appcat)")

# 9. Interaktywna sesja
def interaktywna_sesja():
    """
    Uruchom interaktywną sesję z agentem
    """
    print("\n🚀 INTERAKTYWNA SESJA Z SQL AGENTEM")
    print("Wpisz 'quit' aby zakończyć")
    print("="*60)
    
    while True:
        pytanie = input("\n❓ Twoje pytanie: ")
        
        if pytanie.lower() in ['quit', 'exit', 'koniec']:
            print("👋 Do widzenia!")
            break
            
        if pytanie.strip():
            zapytaj_agenta(pytanie)

# Uruchom interaktywną sesję (odkomentuj poniżej)
# interaktywna_sesja()

# 10. Przydatne funkcje pomocnicze
def pokaz_strukture_tabeli():
    """Pokaż strukturę tabeli logs"""
    conn = sqlite3.connect(Config.DB_PATH)
    cursor = conn.cursor()
    
    cursor.execute("PRAGMA table_info(logs)")
    columns = cursor.fetchall()
    
    print("\n📋 STRUKTURA TABELI 'logs':")
    print("-" * 60)
    print(f"{'Kolumna':<20} {'Typ':<15} {'Nullable':<10}")
    print("-" * 60)
    
    for col in columns:
        nullable = "NO" if col[3] else "YES"
        print(f"{col[1]:<20} {col[2]:<15} {nullable:<10}")
    
    conn.close()

def pokaz_przykladowe_dane(limit=5):
    """Pokaż przykładowe dane z tabeli"""
    conn = sqlite3.connect(Config.DB_PATH)
    
    df = pd.read_sql_query(f"SELECT * FROM logs LIMIT {limit}", conn)
    print(f"\n📊 PRZYKŁADOWE DANE ({limit} rekordów):")
    print("="*100)
    print(df.to_string())
    
    conn.close()

# Uruchom funkcje pomocnicze
pokaz_strukture_tabeli()
pokaz_przykladowe_dane(3)

print("\n🎉 SQL Agent jest gotowy do użycia!")
print("💡 Użyj funkcji zapytaj_agenta('twoje pytanie') aby zadać pytanie")
print("💡 Lub uruchom interaktywna_sesja() dla trybu interaktywnego")
# Out:
# ✅ LLM zainicjalizowany
# ✅ Połączono z bazą danych
#
# 📋 Dostępne tabele:
# ['logs']
#
# 🔍 Struktura tabeli 'logs':
#
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */
# ✅ SQL Agent utworzony
#
# 🔍 Sprawdzanie zawartości bazy...
# 📊 Całkowita liczba rekordów: 29006
# 📅 Zakres dat: 2025-05-16 - 2025-05-20
#
# 👥 Top 5 użytkowników:
#   - Mac: 9004 sesji
#   - PL-FMHQ-P0066: 2776 sesji
#   - PL-FMHQ-M0052: 2484 sesji
#   - None: 2424 sesji
#   - iPhone: 2131 sesji
#
# 📱 Top 5 aplikacji:
#   - Spotify: 13478 sesji
#   - YouTube: 4225 sesji
#   - Facebook: 3723 sesji
#   - LinkedIn: 2322 sesji
#   - Instagram: 1218 sesji
#
# 🧪 TESTY AGENTA
# ============================================================
#
# 🤔 PYTANIE: Ile rekordów jest w tabeli logs?
# ============================================================
#
#
# > Entering new SQL Agent Executor chain...
# /var/folders/g0/0_3w3d415fb5_p5bvx1g2l9r0000gp/T/ipykernel_19864/792026512.py:40: LangChainDeprecationWarning: The method `SQLDatabase.get_table_names` was deprecated in langchain-community 0.0.1 and will be removed in 1.0. Use :meth:`~get_usable_table_names` instead.
#   print(db.get_table_names())
# Action: sql_db_list_tables
# Action Input: ""  logsI need to check the schema of the "logs" table to understand its structure and then count the records in it.
# Action: sql_db_schema
# Action Input: "logs"
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */I need to count the number of records in the "logs" table. I will write a query to do that.
# Action: sql_db_query_checker
# Action Input: "SELECT COUNT(*) AS record_count FROM logs;"  ```sql
# SELECT COUNT(*) AS record_count FROM logs;
# ```The query is correct. Now I will execute it to get the count of records in the "logs" table.
# Action: sql_db_query
# Action Input: "SELECT COUNT(*) AS record_count FROM logs;"  [(29006,)]I now know the final answer.
# Final Answer: W tabeli logs jest 29006 rekordów.
#
# > Finished chain.
#
# ✅ ODPOWIEDŹ:
# W tabeli logs jest 29006 rekordów.
#
# 🤔 PYTANIE: Pokaż mi 5 najaktywniejszych użytkowników
# ============================================================
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  logsThe only table in the database is "logs". I will now check the schema of the "logs" table to identify relevant columns for querying the most active users.
# Action: sql_db_schema
# Action Input: "logs"
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */To find the most active users, I can count the occurrences of each user based on their source IP addresses (`srcip`) in the logs table. I will group the results by `srcip` and order them by the count in descending order, limiting the results to 5.
#
# Action: sql_db_query_checker
# Action Input: "SELECT srcip, COUNT(*) as activity_count FROM logs GROUP BY srcip ORDER BY activity_count DESC LIMIT 5;"  ```sql
# SELECT srcip, COUNT(*) as activity_count FROM logs GROUP BY srcip ORDER BY activity_count DESC LIMIT 5;
# ```The query is syntactically correct. I will now execute it to get the results.
#
# Action: sql_db_query
# Action Input: "SELECT srcip, COUNT(*) as activity_count FROM logs GROUP BY srcip ORDER BY activity_count DESC LIMIT 5;"  [('10.22.7.128', 4747), ('10.22.7.130', 3518), ('10.22.7.135', 2776), ('10.22.7.133', 2516), ('10.22.72.103', 1605)]I now know the final answer. The 5 most active users based on their source IP addresses are:
#
# 1. 10.22.7.128 with 4747 activities
# 2. 10.22.7.130 with 3518 activities
# 3. 10.22.7.135 with 2776 activities
# 4. 10.22.7.133 with 2516 activities
# 5. 10.22.72.103 with 1605 activities
#
# Final Answer: 5 najaktywniejszych użytkowników to:
# 1. 10.22.7.128 - 4747 aktywności
# 2. 10.22.7.130 - 3518 aktywności
# 3. 10.22.7.135 - 2776 aktywności
# 4. 10.22.7.133 - 2516 aktywności
# 5. 10.22.72.103 - 1605 aktywności
#
# > Finished chain.
#
# ✅ ODPOWIEDŹ:
# 5 najaktywniejszych użytkowników to:
# 1. 10.22.7.128 - 4747 aktywności
# 2. 10.22.7.130 - 3518 aktywności
# 3. 10.22.7.135 - 2776 aktywności
# 4. 10.22.7.133 - 2516 aktywności
# 5. 10.22.72.103 - 1605 aktywności
#
# 🤔 PYTANIE: Które aplikacje są najczęściej używane?
# ============================================================
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  logsI need to check the schema of the "logs" table to understand what columns are available for querying.
# Action: sql_db_schema
# Action Input: "logs"
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */To determine which applications are most frequently used, I will query the `logs` table, specifically focusing on the `app` column to count the occurrences of each application. I will group the results by the application name and order them by the count in descending order to find the most frequently used applications.
#
# Action: sql_db_query_checker
# Action Input: "SELECT app, COUNT(*) as usage_count FROM logs GROUP BY app ORDER BY usage_count DESC LIMIT 10;"  ```sql
# SELECT app, COUNT(*) as usage_count FROM logs GROUP BY app ORDER BY usage_count DESC LIMIT 10;
# ```The query is syntactically correct. Now I will execute it to get the results.
#
# Action: sql_db_query
# Action Input: "SELECT app, COUNT(*) as usage_count FROM logs GROUP BY app ORDER BY usage_count DESC LIMIT 10;"  [('Spotify', 13478), ('YouTube', 4225), ('Facebook', 3723), ('LinkedIn', 2322), ('Instagram', 1218), ('Snapchat', 1195), ('TikTok', 821), ('Reddit', 657), ('Twitter', 347), ('Vimeo', 275)]I now know the final answer. The most frequently used applications are:
#
# 1. Spotify - 13,478 uses
# 2. YouTube - 4,225 uses
# 3. Facebook - 3,723 uses
# 4. LinkedIn - 2,322 uses
# 5. Instagram - 1,218 uses
# 6. Snapchat - 1,195 uses
# 7. TikTok - 821 uses
# 8. Reddit - 657 uses
# 9. Twitter - 347 uses
# 10. Vimeo - 275 uses
#
# Final Answer: Najczęściej używane aplikacje to: Spotify, YouTube, Facebook, LinkedIn, Instagram, Snapchat, TikTok, Reddit, Twitter, Vimeo.
#
# > Finished chain.
#
# ✅ ODPOWIEDŹ:
# Najczęściej używane aplikacje to: Spotify, YouTube, Facebook, LinkedIn, Instagram, Snapchat, TikTok, Reddit, Twitter, Vimeo.
#
# 🤔 PYTANIE: Jaki jest całkowity czas spędzony przez użytkownika Dawid w aplikacjach?
# ============================================================
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  logsI need to check the schema of the "logs" table to find relevant columns related to user activity and time spent.
# Action: sql_db_schema
# Action Input: "logs"
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */To find the total time spent by the user "Dawid" in applications, I need to sum the "duration" column from the "logs" table where the "srcname" is "Dawid-s-S23". I will also limit the results to a maximum of 10 entries to ensure the query is efficient.
#
# Action: sql_db_query_checker
# Action Input: "SELECT SUM(duration) AS total_duration FROM logs WHERE srcname = 'Dawid-s-S23'"  ```sql
# SELECT SUM(duration) AS total_duration FROM logs WHERE srcname = 'Dawid-s-S23'
# ```The query is correct. Now I will execute it to get the total duration for the user "Dawid".
#
# Action: sql_db_query
# Action Input: "SELECT SUM(duration) AS total_duration FROM logs WHERE srcname = 'Dawid-s-S23'"  [(1025602,)]I now know the final answer.
# Final Answer: Całkowity czas spędzony przez użytkownika Dawid w aplikacjach wynosi 1,025,602 sekund.
#
# > Finished chain.
#
# ✅ ODPOWIEDŹ:
# Całkowity czas spędzony przez użytkownika Dawid w aplikacjach wynosi 1,025,602 sekund.
#
# 🤔 PYTANIE: Pokaż podział na kategorie aplikacji (appcat)
# ============================================================
#
#
# > Entering new SQL Agent Executor chain...
# Action: sql_db_list_tables
# Action Input: ""  logsI need to check the schema of the "logs" table to see if it contains information about application categories (appcat).
# Action: sql_db_schema
# Action Input: "logs"
# CREATE TABLE logs (
# 	date TEXT,
# 	time TEXT,
# 	eventtime TEXT,
# 	logid TEXT,
# 	srcip TEXT,
# 	srcname TEXT,
# 	srcport INTEGER,
# 	dstip TEXT,
# 	dstport INTEGER,
# 	proto INTEGER,
# 	action TEXT,
# 	policyname TEXT,
# 	service TEXT,
# 	transport TEXT,
# 	appid TEXT,
# 	app TEXT,
# 	appcat TEXT,
# 	apprisk TEXT,
# 	duration INTEGER,
# 	sentbyte INTEGER,
# 	rcvdbyte INTEGER,
# 	sentpkt INTEGER,
# 	rcvdpkt INTEGER,
# 	shapersentname TEXT,
# 	osname TEXT,
# 	mastersrcmac TEXT
# )
#
# /*
# 3 rows from logs table:
# date	time	eventtime	logid	srcip	srcname	srcport	dstip	dstport	proto	action	policyname	service	transport	appid	app	appcat	apprisk	duration	sentbyte	rcvdbyte	sentpkt	rcvdpkt	shapersentname	osname	mastersrcmac
# 2025-05-16	10:19:02	1747383542538331649	0000000013	10.22.7.133	Dawid-s-S23	33232	57.144.112.141	443	6	close	LAN2WAN	HTTPS	33232	15832	Facebook	Social.Media	medium	1	2070	1707	9	7	medium-priority	Android	ee:ec:bd:03:c4:82
# 2025-05-16	10:19:04	1747383544968280615	0000000013	10.22.76.104	iPhone	53447	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53447	15832	Facebook	Social.Media	medium	10	6185	93293	55	84	medium-priority	iOS	1e:ea:73:e5:55:b0
# 2025-05-16	10:19:04	1747383544988308244	0000000013	10.22.76.104	iPhone	53448	57.144.112.141	443	6	client-rst	PC2INT	HTTPS	53448	15832	Facebook	Social.Media	medium	10	2204	6277	13	11	medium-priority	iOS	1e:ea:73:e5:55:b0
# */The "logs" table contains a column named "appcat" which represents the application categories. I will now query this table to get a list of distinct application categories (appcat) and limit the results to 10 entries.
#
# Action: sql_db_query
# Action Input: "SELECT DISTINCT appcat FROM logs LIMIT 10;"  [('Social.Media',), ('Video/Audio',), ('Game',)]I now know the final answer.
# Final Answer: The application categories (appcat) are: Social.Media, Video/Audio, and Game.
#
# > Finished chain.
#
# ✅ ODPOWIEDŹ:
# The application categories (appcat) are: Social.Media, Video/Audio, and Game.
#
# 📋 STRUKTURA TABELI 'logs':
# ------------------------------------------------------------
# Kolumna              Typ             Nullable
# ------------------------------------------------------------
# date                 TEXT            YES
# time                 TEXT            YES
# eventtime            TEXT            YES
# logid                TEXT            YES
# srcip                TEXT            YES
# srcname              TEXT            YES
# srcport              INTEGER         YES
# dstip                TEXT            YES
# dstport              INTEGER         YES
# proto                INTEGER         YES
# action               TEXT            YES
# policyname           TEXT            YES
# service              TEXT            YES
# transport            TEXT            YES
# appid                TEXT            YES
# app                  TEXT            YES
# appcat               TEXT            YES
# apprisk              TEXT            YES
# duration             INTEGER         YES
# sentbyte             INTEGER         YES
# rcvdbyte             INTEGER         YES
# sentpkt              INTEGER         YES
# rcvdpkt              INTEGER         YES
# shapersentname       TEXT            YES
# osname               TEXT            YES
# mastersrcmac         TEXT            YES
#
# 📊 PRZYKŁADOWE DANE (3 rekordów):
# ====================================================================================================
#          date      time            eventtime       logid         srcip      srcname  srcport           dstip  dstport  proto      action policyname service transport  appid       app        appcat apprisk  duration  sentbyte  rcvdbyte  sentpkt  rcvdpkt   shapersentname   osname       mastersrcmac
# 0  2025-05-16  10:19:02  1747383542538331649  0000000013   10.22.7.133  Dawid-s-S23    33232  57.144.112.141      443      6       close    LAN2WAN   HTTPS     33232  15832  Facebook  Social.Media  medium         1      2070      1707        9        7  medium-priority  Android  ee:ec:bd:03:c4:82
# 1  2025-05-16  10:19:04  1747383544968280615  0000000013  10.22.76.104       iPhone    53447  57.144.112.141      443      6  client-rst     PC2INT   HTTPS     53447  15832  Facebook  Social.Media  medium        10      6185     93293       55       84  medium-priority      iOS  1e:ea:73:e5:55:b0
# 2  2025-05-16  10:19:04  1747383544988308244  0000000013  10.22.76.104       iPhone    53448  57.144.112.141      443      6  client-rst     PC2INT   HTTPS     53448  15832  Facebook  Social.Media  medium        10      2204      6277       13       11  medium-priority      iOS  1e:ea:73:e5:55:b0
#
# 🎉 SQL Agent jest gotowy do użycia!
# 💡 Użyj funkcji zapytaj_agenta('twoje pytanie') aby zadać pytanie
# 💡 Lub uruchom interaktywna_sesja() dla trybu interaktywnego
